# %%
import pandas as pd

# %%
df = pd.read_csv("Taxi_Trips_-_2019.tsv", header=0, delimiter="\t")

# %%
df.columns.values.tolist()
# Out:
# ['Trip ID',
#  'Taxi ID',
#  'Trip Start Timestamp',
#  'Trip End Timestamp',
#  'Trip Seconds',
#  'Trip Miles',
#  'Pickup Census Tract',
#  'Dropoff Census Tract',
#  'Pickup Community Area',
#  'Dropoff Community Area',
#  'Fare',
#  'Tips',
#  'Tolls',
#  'Extras',
#  'Trip Total',
#  'Payment Type',
#  'Company',
#  'Pickup Centroid Latitude',
#  'Pickup Centroid Longitude',
#  'Pickup Centroid Location',
#  'Dropoff Centroid Latitude',
#  'Dropoff Centroid Longitude',
#  'Dropoff Centroid  Location']

# %%
# 3.Trip Start Timestamp (string -> date and time)
# 5. Trip Seconds (int)
# 6. Trip Miles (float)
# 9. Pickup Community Area (int)
# 10. Drop-off community Area (int)
# 17. Company (string)
df = df[['Trip Start Timestamp', 'Trip Seconds', 'Trip Miles', 'Pickup Community Area', 'Dropoff Community Area', 'Company']]
df.head(5)
# keep only necessary columns
# Out:
#      Trip Start Timestamp  Trip Seconds  Trip Miles  Pickup Community Area  \
# 0  01/01/2019 12:00:00 AM         885.0        3.45                    NaN
# 1  01/01/2019 12:00:00 AM           8.0        0.00                    NaN
# 2  01/01/2019 12:00:00 AM         960.0        4.90                    NaN
# 3  01/01/2019 12:00:00 AM         420.0        1.50                    NaN
# 4  01/01/2019 12:00:00 AM         420.0        0.50                    NaN
#
#    Dropoff Community Area                    Company
# 0                     NaN                  Flash Cab
# 1                     NaN  Chicago Carriage Cab Corp
# 2                     NaN  Star North Management LLC
# 3                     NaN  Star North Management LLC
# 4                     NaN  Star North Management LLC

# %%
df = df[df['Pickup Community Area'].notnull() & df['Dropoff Community Area'].notnull()]
df
#delete community areas NaN since those are outside of chicago.
#14629392 rows × 6 columns
# Out:
#             Trip Start Timestamp  Trip Seconds  Trip Miles  \
# 16        01/01/2019 12:00:00 AM         600.0        0.00
# 18        01/01/2019 12:00:00 AM        1260.0        0.60
# 19        01/01/2019 12:00:00 AM         120.0        0.30
# 20        01/01/2019 12:00:00 AM         360.0        0.80
# 22        01/01/2019 12:00:00 AM         360.0        1.00
# ...                          ...           ...         ...
# 16477360  12/31/2019 11:45:00 PM        1639.0        4.10
# 16477361  12/31/2019 11:45:00 PM        2040.0       18.30
# 16477362  12/31/2019 11:45:00 PM        4271.0       17.81
# 16477363  12/31/2019 11:45:00 PM         600.0        1.30
# 16477364  12/31/2019 11:45:00 PM        1303.0        2.90
#
#           Pickup Community Area  Dropoff Community Area  \
# 16                          8.0                    32.0
# 18                         77.0                    28.0
# 19                         32.0                    32.0
# 20                          8.0                     8.0
# 22                          8.0                     8.0
# ...                         ...                     ...
# 16477360                    7.0                    32.0
# 16477361                   76.0                     8.0
# 16477362                   56.0                     8.0
# 16477363                   32.0                     8.0
# 16477364                    8.0                    32.0
#
#                                     Company
# 16        Blue Ribbon Taxi Association Inc.
# 18        Blue Ribbon Taxi Association Inc.
# 19                Star North Management LLC
# 20                Taxi Affiliation Services
# 22                Taxi Affiliation Services
# ...                                     ...
# 16477360                           Sun Taxi
# 16477361       4053 - 40193 Adwar H. Nikola
# 16477362          Chicago Carriage Cab Corp
# 16477363          Star North Management LLC
# 16477364          Chicago Carriage Cab Corp
#
# [14629392 rows x 6 columns]

# %%
# remove all trips less than 0.5 miles, and more than 100 miles
# df[df['Trip Miles'] < 0.5]
df = df[(df['Trip Miles'] >= 0.5) & (df['Trip Miles'] <= 100)]
df
# 11410676 rows × 6 columns
# Out:
#             Trip Start Timestamp  Trip Seconds  Trip Miles  \
# 18        01/01/2019 12:00:00 AM        1260.0        0.60
# 20        01/01/2019 12:00:00 AM         360.0        0.80
# 22        01/01/2019 12:00:00 AM         360.0        1.00
# 23        01/01/2019 12:00:00 AM         420.0        0.80
# 24        01/01/2019 12:00:00 AM         180.0        0.70
# ...                          ...           ...         ...
# 16477360  12/31/2019 11:45:00 PM        1639.0        4.10
# 16477361  12/31/2019 11:45:00 PM        2040.0       18.30
# 16477362  12/31/2019 11:45:00 PM        4271.0       17.81
# 16477363  12/31/2019 11:45:00 PM         600.0        1.30
# 16477364  12/31/2019 11:45:00 PM        1303.0        2.90
#
#           Pickup Community Area  Dropoff Community Area  \
# 18                         77.0                    28.0
# 20                          8.0                     8.0
# 22                          8.0                     8.0
# 23                          8.0                     8.0
# 24                         77.0                     4.0
# ...                         ...                     ...
# 16477360                    7.0                    32.0
# 16477361                   76.0                     8.0
# 16477362                   56.0                     8.0
# 16477363                   32.0                     8.0
# 16477364                    8.0                    32.0
#
#                                     Company
# 18        Blue Ribbon Taxi Association Inc.
# 20                Taxi Affiliation Services
# 22                Taxi Affiliation Services
# 23            Taxicab Insurance Agency, LLC
# 24                Taxi Affiliation Services
# ...                                     ...
# 16477360                           Sun Taxi
# 16477361       4053 - 40193 Adwar H. Nikola
# 16477362          Chicago Carriage Cab Corp
# 16477363          Star North Management LLC
# 16477364          Chicago Carriage Cab Corp
#
# [11410676 rows x 6 columns]

# %%
# remove less than 60 seconds, and greater than 5 hours (18,000 secs)
# df[df['Trip Seconds'] > 18000]
df = df[(df['Trip Seconds'] >= 60) & (df['Trip Miles'] <= 18000)]
df
# 11403451 rows × 6 columns
# Out:
#             Trip Start Timestamp  Trip Seconds  Trip Miles  \
# 18        01/01/2019 12:00:00 AM        1260.0        0.60
# 20        01/01/2019 12:00:00 AM         360.0        0.80
# 22        01/01/2019 12:00:00 AM         360.0        1.00
# 23        01/01/2019 12:00:00 AM         420.0        0.80
# 24        01/01/2019 12:00:00 AM         180.0        0.70
# ...                          ...           ...         ...
# 16477360  12/31/2019 11:45:00 PM        1639.0        4.10
# 16477361  12/31/2019 11:45:00 PM        2040.0       18.30
# 16477362  12/31/2019 11:45:00 PM        4271.0       17.81
# 16477363  12/31/2019 11:45:00 PM         600.0        1.30
# 16477364  12/31/2019 11:45:00 PM        1303.0        2.90
#
#           Pickup Community Area  Dropoff Community Area  \
# 18                         77.0                    28.0
# 20                          8.0                     8.0
# 22                          8.0                     8.0
# 23                          8.0                     8.0
# 24                         77.0                     4.0
# ...                         ...                     ...
# 16477360                    7.0                    32.0
# 16477361                   76.0                     8.0
# 16477362                   56.0                     8.0
# 16477363                   32.0                     8.0
# 16477364                    8.0                    32.0
#
#                                     Company
# 18        Blue Ribbon Taxi Association Inc.
# 20                Taxi Affiliation Services
# 22                Taxi Affiliation Services
# 23            Taxicab Insurance Agency, LLC
# 24                Taxi Affiliation Services
# ...                                     ...
# 16477360                           Sun Taxi
# 16477361       4053 - 40193 Adwar H. Nikola
# 16477362          Chicago Carriage Cab Corp
# 16477363          Star North Management LLC
# 16477364          Chicago Carriage Cab Corp
#
# [11403451 rows x 6 columns]

# %%
df.to_csv("taxi_data_all.csv", index=False, header=True, mode='a')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11188/2332593121.py in <module>
# ----> 1 df.to_csv("taxi_data_all.csv", index=False, header=True, mode='a')
#
# NameError: name 'df' is not defined

# %%
##
df = pd.read_table("taxi_data_all.csv", header=0, delimiter=",")

# %%
df
# Out:
#             Trip Start Timestamp  Trip Seconds  Trip Miles  \
# 0         01/01/2019 12:00:00 AM        1260.0        0.60
# 1         01/01/2019 12:00:00 AM         360.0        0.80
# 2         01/01/2019 12:00:00 AM         360.0        1.00
# 3         01/01/2019 12:00:00 AM         420.0        0.80
# 4         01/01/2019 12:00:00 AM         180.0        0.70
# ...                          ...           ...         ...
# 11403446  12/31/2019 11:45:00 PM        1639.0        4.10
# 11403447  12/31/2019 11:45:00 PM        2040.0       18.30
# 11403448  12/31/2019 11:45:00 PM        4271.0       17.81
# 11403449  12/31/2019 11:45:00 PM         600.0        1.30
# 11403450  12/31/2019 11:45:00 PM        1303.0        2.90
#
#           Pickup Community Area  Dropoff Community Area  \
# 0                          77.0                    28.0
# 1                           8.0                     8.0
# 2                           8.0                     8.0
# 3                           8.0                     8.0
# 4                          77.0                     4.0
# ...                         ...                     ...
# 11403446                    7.0                    32.0
# 11403447                   76.0                     8.0
# 11403448                   56.0                     8.0
# 11403449                   32.0                     8.0
# 11403450                    8.0                    32.0
#
#                                     Company
# 0         Blue Ribbon Taxi Association Inc.
# 1                 Taxi Affiliation Services
# 2                 Taxi Affiliation Services
# 3             Taxicab Insurance Agency, LLC
# 4                 Taxi Affiliation Services
# ...                                     ...
# 11403446                           Sun Taxi
# 11403447       4053 - 40193 Adwar H. Nikola
# 11403448          Chicago Carriage Cab Corp
# 11403449          Star North Management LLC
# 11403450          Chicago Carriage Cab Corp
#
# [11403451 rows x 6 columns]

# %%
## change company column to a col of integers that reference the company name in another table
df = pd.read_csv("taxi_data_clean.tsv", header=0, delimiter="\t")

# %%
df
# Out:
#           secs  miles  pickup  dropoff                            company  \
# 0         1260   0.60      77       28  Blue Ribbon Taxi Association Inc.
# 1          360   0.80       8        8          Taxi Affiliation Services
# 2          360   1.00       8        8          Taxi Affiliation Services
# 3          420   0.80       8        8      Taxicab Insurance Agency, LLC
# 4          180   0.70      77        4          Taxi Affiliation Services
# ...        ...    ...     ...      ...                                ...
# 11403446  1639   4.10       7       32                           Sun Taxi
# 11403447  2040  18.30      76        8       4053 - 40193 Adwar H. Nikola
# 11403448  4271  17.81      56        8          Chicago Carriage Cab Corp
# 11403449   600   1.30      32        8          Star North Management LLC
# 11403450  1303   2.90       8       32          Chicago Carriage Cab Corp
#
#                 date  hour  year  month  day
# 0         2019-01-01     0  2019      1  Tue
# 1         2019-01-01     0  2019      1  Tue
# 2         2019-01-01     0  2019      1  Tue
# 3         2019-01-01     0  2019      1  Tue
# 4         2019-01-01     0  2019      1  Tue
# ...              ...   ...   ...    ...  ...
# 11403446  2019-12-31    23  2019     12  Tue
# 11403447  2019-12-31    23  2019     12  Tue
# 11403448  2019-12-31    23  2019     12  Tue
# 11403449  2019-12-31    23  2019     12  Tue
# 11403450  2019-12-31    23  2019     12  Tue
#
# [11403451 rows x 10 columns]

# %%
# df.head(200)
comps = pd.DataFrame(data=df['company'].unique())
comps.reset_index(inplace=True)
comps.columns = ['id', 'company' ]
comps
# Out:
#     id                                       company
# 0    0             Blue Ribbon Taxi Association Inc.
# 1    1                     Taxi Affiliation Services
# 2    2                 Taxicab Insurance Agency, LLC
# 3    3                       Choice Taxi Association
# 4    4                     Star North Management LLC
# 5    5                           Top Cab Affiliation
# 6    6                          Chicago Independents
# 7    7                         KOAM Taxi Association
# 8    8                   1085 - 72312 N and W Cab Co
# 9    9                  Chicago Medallion Management
# 10  10                     Chicago Carriage Cab Corp
# 11  11                                     Flash Cab
# 12  12                                    Globe Taxi
# 13  13          Patriot Taxi Dba Peace Taxi Associat
# 14  14                                  City Service
# 15  15                                 24 Seven Taxi
# 16  16                                      Sun Taxi
# 17  17                              Medallion Leasin
# 18  18               Taxi Affiliation Service Yellow
# 19  19                     Nova Taxi Affiliation Llc
# 20  20                               Gold Coast Taxi
# 21  21                               Chicago Taxicab
# 22  22                                  Blue Diamond
# 23  23                                    Yellow Cab
# 24  24                 312 Medallion Management Corp
# 25  25                      Checker Taxi Affiliation
# 26  26                                   5 Star Taxi
# 27  27                              Metro Jet Taxi A
# 28  28                                  Checker Taxi
# 29  29                   6742 - 83735 Tasha ride inc
# 30  30                                    Setare Inc
# 31  31              American United Taxi Affiliation
# 32  32                        1469 - 64126 Omar Jada
# 33  33                               American United
# 34  34                       6743 - 78771 Luhak Corp
# 35  35                                Leonard Cab Co
# 36  36                  4053 - 40193 Adwar H. Nikola
# 37  37                     3011 - 66308 JBL Cab Inc.
# 38  38                          4623 - 27290 Jay Kim
# 39  39                    3094 - 24059 G.L.B. Cab Co
# 40  40                    2092 - 61288 Sbeih company
# 41  41                       2733 - 74600 Benny Jona
# 42  42                   6574 - Babylon Express Inc.
# 43  43            3623 - 72222 Arrington Enterprises
# 44  44                          Chicago Star Taxicab
# 45  45  3721 - Santamaria Express, Alvaro Santamaria
# 46  46                      5006 - 39261 Salifu Bawa
# 47  47                       5062 - 34841 Sam Mestas
# 48  48                        5074 - 54002 Ahzmi Inc
# 49  49               3620 - 52292 David K. Cab Corp.
# 50  50                 5874 - 73628 Sergey Cab Corp.
# 51  51                        3591 - 63480 Chuks Cab
# 52  52                               Petani Cab Corp
# 53  53                                     U Taxicab
# 54  54                   3556 - 36214 RC Andrews Cab

# %%
comps.to_csv("companies.csv", index=False, header=True, mode='a')

# %%
comps.loc[(comps['company'] == 'Flash Cab'), 'id']
# Out:
# 11    11
# Name: id, dtype: int64

# %%
df = df.assign(company_id=lambda x: comps.loc[(comps['company'] == x.company), 'id'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11188/158830598.py in <module>
# ----> 1 df = df.assign(company_id=lambda x: comps.loc[(comps['company'] == x.company), 'id'])
#
# ~\anaconda3\envs\r-env\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    4504
#    4505         for k, v in kwargs.items():
# -> 4506             data[k] = com.apply_if_callable(v, data)
#    4507         return data
#    4508
#
# ~\anaconda3\envs\r-env\lib\site-packages\pandas\core\common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     356     """
#     357     if callable(maybe_callable):
# --> 358         return maybe_callable(obj, **kwargs)
#     359
#     360     return maybe_callable
#
# ~\AppData\Local\Temp/ipykernel_11188/158830598.py in <lambda>(x)
# ----> 1 df = df.assign(company_id=lambda x: comps.loc[(comps['company'] == x.company), 'id'])
#
# ~\anaconda3\envs\r-env\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\anaconda3\envs\r-env\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
#      42     @unpack_zerodim_and_defer("__ne__")
#
# ~\anaconda3\envs\r-env\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5615
#    5616         if isinstance(other, Series) and not self._indexed_same(other):
# -> 5617             raise ValueError("Can only compare identically-labeled Series objects")
#    5618
#    5619         lvalues = self._values
#
# ValueError: Can only compare identically-labeled Series objects
